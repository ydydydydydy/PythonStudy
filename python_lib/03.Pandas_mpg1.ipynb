# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
# csv 방법 pd.read_csv(파일명)
mpg_data = pd.read_csv('data/mpg.csv')

# %%
mpg_data
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# 상단에 n개의 데이터를 보고 싶은 경우
# .head() 기본값은 (미작성시) 5개

# %%
mpg_data.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
# 하단에 있는 데이터 n개 출력
# .tail() - 미작성시 기본값 5개
mpg_data.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize

# %%
# 데이터가 가지고 있는 정보를 출력하는 함수
# .info
mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg_data.shape
# Out:
# (234, 11)

# %%
# 요약 통계
# .describe()
mpg_data.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# #### 간단한 insight
#  - 도시연비가 가장낮은 차는 1갤런당 9마일
#  - 고속도로 연비가 가장 낮은 차는 12마일
#
#  - 도시연비에서 연비가 가장 좋은 차는 35마일
#  - 고속도로 연비가 가장 좋은 차는 44마일
#
#  - 도시연비의 경우 가장 낮은 차와 가장 높은 차의 차이는 약 4배

# %%
# 문자도 요약통계
mpg_data.describe(include = 'all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %% [markdown]
# ### 변수명 바꾸기

# %%
# 기존데이터를 수정할땐 copy 만들기 추천
mpg_copy = mpg_data.copy()

# %%
mpg_copy
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# .rename()
mpg_copy = mpg_copy.rename(columns= {"manufacturer" : "제조사", "cyl": "실린더" , "cty" :"도시" , "hwy" : "고속도로" , "fl" : "연료"})
mpg_copy
# Out:
#             제조사   model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f  18    29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f  21    29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f  20    31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f  21    30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f  16    26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ..   ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
# 도시와 고속도로의 연비를 구한 후에 평균
# 데이터 접근
# 1. 도시 접근
display(mpg_copy['도시'])

# 2. 고속도로 연비 접근
display(mpg_copy['고속도로'])

# 도시 + 고속도로 / 2
display((mpg_copy['도시'] + mpg_copy['고속도로']) /2 )
# Out:
# 0      18
# 1      21
# 2      20
# 3      21
# 4      16
#        ..
# 229    19
# 230    21
# 231    16
# 232    18
# 233    17
# Name: 도시, Length: 234, dtype: int64
# 0      29
# 1      29
# 2      31
# 3      30
# 4      26
#        ..
# 229    28
# 230    29
# 231    26
# 232    26
# 233    26
# Name: 고속도로, Length: 234, dtype: int64
# 0      23.5
# 1      25.0
# 2      25.5
# 3      25.5
# 4      21.0
#        ...
# 229    23.5
# 230    25.0
# 231    21.0
# 232    22.0
# 233    21.5
# Length: 234, dtype: float64

# %%
# loc, iloc 인덱서 사용
mpg_copy.loc[0]
# Out:
# 제조사             audi
# model             a4
# displ            1.8
# year            1999
# 실린더                4
# trans       auto(l5)
# drv                f
# 도시                18
# 고속도로              29
# 연료                 p
# category     compact
# Name: 0, dtype: object

# %%
mpg_copy.iloc[0]
# Out:
# 제조사             audi
# model             a4
# displ            1.8
# year            1999
# 실린더                4
# trans       auto(l5)
# drv                f
# 도시                18
# 고속도로              29
# 연료                 p
# category     compact
# Name: 0, dtype: object

# %%
mpg_index = mpg_copy.set_index('제조사')
mpg_index
# Out:
#              model  displ  year  실린더       trans drv  도시  고속도로 연료 category
# 제조사
# audi            a4    1.8  1999    4    auto(l5)   f  18    29  p  compact
# audi            a4    1.8  1999    4  manual(m5)   f  21    29  p  compact
# audi            a4    2.0  2008    4  manual(m6)   f  20    31  p  compact
# audi            a4    2.0  2008    4    auto(av)   f  21    30  p  compact
# audi            a4    2.8  1999    6    auto(l5)   f  16    26  p  compact
# ...            ...    ...   ...  ...         ...  ..  ..   ... ..      ...
# volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p  midsize
# volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p  midsize
# volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p  midsize
# volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p  midsize
# volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p  midsize
#
# [234 rows x 10 columns]

# %%
mpg_index.iloc[0]
# Out:
# model             a4
# displ            1.8
# year            1999
# 실린더                4
# trans       auto(l5)
# drv                f
# 도시                18
# 고속도로              29
# 연료                 p
# category     compact
# Name: audi, dtype: object

# %%
mpg_index.loc['audi']
# Out:
#            model  displ  year  실린더       trans drv  도시  고속도로 연료 category
# 제조사
# audi          a4    1.8  1999    4    auto(l5)   f  18    29  p  compact
# audi          a4    1.8  1999    4  manual(m5)   f  21    29  p  compact
# audi          a4    2.0  2008    4  manual(m6)   f  20    31  p  compact
# audi          a4    2.0  2008    4    auto(av)   f  21    30  p  compact
# audi          a4    2.8  1999    6    auto(l5)   f  16    26  p  compact
# audi          a4    2.8  1999    6  manual(m5)   f  18    26  p  compact
# audi          a4    3.1  2008    6    auto(av)   f  18    27  p  compact
# audi  a4 quattro    1.8  1999    4  manual(m5)   4  18    26  p  compact
# audi  a4 quattro    1.8  1999    4    auto(l5)   4  16    25  p  compact
# audi  a4 quattro    2.0  2008    4  manual(m6)   4  20    28  p  compact
# audi  a4 quattro    2.0  2008    4    auto(s6)   4  19    27  p  compact
# audi  a4 quattro    2.8  1999    6    auto(l5)   4  15    25  p  compact
# ...

# %%
# loc - 슬라이싱
mpg_index.loc['audi' : 'hyundai']
# Out:
#            model  displ  year  실린더       trans drv  도시  고속도로 연료    category
# 제조사
# audi          a4    1.8  1999    4    auto(l5)   f  18    29  p     compact
# audi          a4    1.8  1999    4  manual(m5)   f  21    29  p     compact
# audi          a4    2.0  2008    4  manual(m6)   f  20    31  p     compact
# audi          a4    2.0  2008    4    auto(av)   f  21    30  p     compact
# audi          a4    2.8  1999    6    auto(l5)   f  16    26  p     compact
# ...          ...    ...   ...  ...         ...  ..  ..   ... ..         ...
# hyundai  tiburon    2.0  2008    4  manual(m5)   f  20    28  r  subcompact
# hyundai  tiburon    2.0  2008    4    auto(l4)   f  20    27  r  subcompact
# hyundai  tiburon    2.7  2008    6    auto(l4)   f  17    24  r  subcompact
# hyundai  tiburon    2.7  2008    6  manual(m6)   f  16    24  r  subcompact
# hyundai  tiburon    2.7  2008    6  manual(m5)   f  17    24  r  subcompact
#
# [122 rows x 10 columns]

# %%
mpg_index.loc['audi' : 'hyundai','고속도로']
# Out:
#          도시  고속도로
# 제조사
# audi     18    29
# audi     21    29
# audi     20    31
# audi     21    30
# audi     16    26
# ...      ..   ...
# hyundai  20    28
# hyundai  20    27
# hyundai  17    24
# hyundai  16    24
# hyundai  17    24
#
# [122 rows x 2 columns]

# %%
mpg_index.loc['audi' : 'hyundai','고속도로':'고속도로']

# %%
mpg_index.iloc[0 : 10]
# Out:
#            model  displ  year  실린더       trans drv  도시  고속도로 연료 category
# 제조사
# audi          a4    1.8  1999    4    auto(l5)   f  18    29  p  compact
# audi          a4    1.8  1999    4  manual(m5)   f  21    29  p  compact
# audi          a4    2.0  2008    4  manual(m6)   f  20    31  p  compact
# audi          a4    2.0  2008    4    auto(av)   f  21    30  p  compact
# audi          a4    2.8  1999    6    auto(l5)   f  16    26  p  compact
# audi          a4    2.8  1999    6  manual(m5)   f  18    26  p  compact
# audi          a4    3.1  2008    6    auto(av)   f  18    27  p  compact
# audi  a4 quattro    1.8  1999    4  manual(m5)   4  18    26  p  compact
# audi  a4 quattro    1.8  1999    4    auto(l5)   4  16    25  p  compact
# audi  a4 quattro    2.0  2008    4  manual(m6)   4  20    28  p  compact

# %% [markdown]
# ### 불리언 인덱싱

# %%
mpg_copy[mpg_copy['도시']>20]
# Out:
#             제조사         model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 1          audi            a4    1.8  1999    4  manual(m5)   f  21    29  p
# 3          audi            a4    2.0  2008    4    auto(av)   f  21    30  p
# 33    chevrolet        malibu    2.4  2008    4    auto(l4)   f  22    30  r
# 99        honda         civic    1.6  1999    4  manual(m5)   f  28    33  r
# 100       honda         civic    1.6  1999    4    auto(l4)   f  24    32  r
# 101       honda         civic    1.6  1999    4  manual(m5)   f  25    32  r
# 102       honda         civic    1.6  1999    4  manual(m5)   f  23    29  p
# 103       honda         civic    1.6  1999    4    auto(l4)   f  24    32  r
# 104       honda         civic    1.8  2008    4  manual(m5)   f  26    34  r
# 105       honda         civic    1.8  2008    4    auto(l5)   f  25    36  r
# 106       honda         civic    1.8  2008    4    auto(l5)   f  24    36  c
# ...

# %%
# 제조사만 보고 싶은경우
mpg_copy[mpg_copy['도시'] > 20]['제조사']
# Out:
# 1            audi
# 3            audi
# 33      chevrolet
# 99          honda
# 100         honda
# 101         honda
# 102         honda
# 103         honda
# 104         honda
# 105         honda
# 106         honda
# 107         honda
# 110       hyundai
# 111       hyundai
# 141        nissan
# 143        nissan
# 144        nissan
# 165        subaru
# 179        toyota
# 180        toyota
# 181        toyota
# 182        toyota
# 186        toyota
# 187        toyota
# 188        toyota
# 189        toyota
# 193        toyota
# 194        toyota
# 195        toyota
# 196        toyota
# 197        toyota
# 207    volkswagen
# 209    volkswagen
# 210    volkswagen
# 212    volkswagen
# 213    volkswagen
# 215    volkswagen
# 216    volkswagen
# 217    volkswagen
# 218    volkswagen
# 221    volkswagen
# 222    volkswagen
# 223    volkswagen
# 227    volkswagen
# 230    volkswagen
# Name: 제조사, dtype: object

# %%
# query 함수
mpg_copy.query('도시 > 20')
# Out:
#             제조사         model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 1          audi            a4    1.8  1999    4  manual(m5)   f  21    29  p
# 3          audi            a4    2.0  2008    4    auto(av)   f  21    30  p
# 33    chevrolet        malibu    2.4  2008    4    auto(l4)   f  22    30  r
# 99        honda         civic    1.6  1999    4  manual(m5)   f  28    33  r
# 100       honda         civic    1.6  1999    4    auto(l4)   f  24    32  r
# 101       honda         civic    1.6  1999    4  manual(m5)   f  25    32  r
# 102       honda         civic    1.6  1999    4  manual(m5)   f  23    29  p
# 103       honda         civic    1.6  1999    4    auto(l4)   f  24    32  r
# 104       honda         civic    1.8  2008    4  manual(m5)   f  26    34  r
# 105       honda         civic    1.8  2008    4    auto(l5)   f  25    36  r
# 106       honda         civic    1.8  2008    4    auto(l5)   f  24    36  c
# ...

# %% [markdown]
# ### 파생변수 만들기
#
# - 컬럼 추가
# - 데이터명['새로운 컬럼명'] = 데이터 대입

# %%
mpg_mean = (mpg_copy['도시'] + mpg_copy['고속도로']) / 2
mpg_mean
# Out:
# 0      23.5
# 1      25.0
# 2      25.5
# 3      25.5
# 4      21.0
#        ...
# 229    23.5
# 230    25.0
# 231    21.0
# 232    22.0
# 233    21.5
# Length: 234, dtype: float64

# %%
mpg_copy['평균'] = mpg_mean

# %%
mpg_copy
# Out:
#             제조사   model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f  18    29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f  21    29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f  20    31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f  21    30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f  16    26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ..   ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p
#
#     category    평균
# 0    compact  23.5
# 1    compact  25.0
# 2    compact  25.5
# 3    compact  25.5
# ...

# %%
mpg_copy['평균']
# Out:
# 0      23.5
# 1      25.0
# 2      25.5
# 3      25.5
# 4      21.0
#        ...
# 229    23.5
# 230    25.0
# 231    21.0
# 232    22.0
# 233    21.5
# Name: 평균, Length: 234, dtype: float64

# %%
mpg_copy['평균'].mean()
# Out:
# 20.14957264957265

# %%
# 1. exam 데이터불러오기

exam_data = pd.read_csv('data/exam.csv')
exam_data
# Out:
#      id  nclass  math  english  science
# 0     1       1    52       98       50
# 1     2       1    60       97       58
# 2     3       1    44       86       78
# 3     4       1    35       98       58
# 4     5       1    27       80       65
# ..  ...     ...   ...      ...      ...
# 95   96       5    58       98       65
# 96   97       5    65       68       98
# 97   98       5    80       78       90
# 98   99       5    89       68       87
# 99  100       5    78       83       58
#
# [100 rows x 5 columns]

# %%
# 2. exam데이터의 정보 확인해보기

exam_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       100 non-null    int64
#  1   nclass   100 non-null    int64
#  2   math     100 non-null    int64
#  3   english  100 non-null    int64
#  4   science  100 non-null    int64
# dtypes: int64(5)
# memory usage: 4.0 KB

# %%
# 3. exam데이터의 요약보기
exam_data.describe(include = 'all')
# Out:
#                id      nclass        math     english     science
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    50.500000    3.000000   59.070000   83.460000   65.310000
# std     29.011492    1.421338   19.748037   12.746495   20.917198
# min      1.000000    1.000000   20.000000   45.000000   12.000000
# 25%     25.750000    2.000000   46.000000   78.000000   53.500000
# 50%     50.500000    3.000000   56.500000   85.500000   65.000000
# 75%     75.250000    4.000000   78.000000   97.000000   78.000000
# max    100.000000    5.000000  100.000000  100.000000  100.000000

# %%
# 4. exam데이터의 각 평균값 구하기
exam_copy = exam_data.copy()
exam_score = (exam_copy['math'] + exam_copy['english'] + exam_copy['science']) / 3
exam_score = (exam_copy.iloc[:,2:5])
exam_mean = exam_score.mean(axis = 1)
rounded_mean = round(exam_mean, 1)
rounded_mean
# Out:
# 0     66.7
# 1     71.7
# 2     69.3
# 3     63.7
# 4     57.3
#       ...
# 95    73.7
# 96    77.0
# 97    82.7
# 98    81.3
# 99    73.0
# Length: 100, dtype: float64

# %%
# 5. 평균 컬럼 파생변수 만들기
exam_copy['평균'] = rounded_mean
exam_copy
# Out:
#      id  nclass  math  english  science    평균
# 0     1       1    52       98       50  66.7
# 1     2       1    60       97       58  71.7
# 2     3       1    44       86       78  69.3
# 3     4       1    35       98       58  63.7
# 4     5       1    27       80       65  57.3
# ..  ...     ...   ...      ...      ...   ...
# 95   96       5    58       98       65  73.7
# 96   97       5    65       68       98  77.0
# 97   98       5    80       78       90  82.7
# 98   99       5    89       68       87  81.3
# 99  100       5    78       83       58  73.0
#
# [100 rows x 6 columns]

# %%
# 조건에 따라 다른 값을 부여하는 파생변수를 만들어 컬럼 추가
# 평균연비가 20 이상이면 통과(pass) 아니면 fail 작성된 컬럼을 추가
# numpy에 있는 where 함수
import numpy as np

# %%
# where() 함수 사용법
# where(조건식, True일때, False일때)

mpg_copy['test 결과'] = np.where(mpg_copy['평균'] > 20, 'pass', 'fail')
mpg_copy
# Out:
#             제조사   model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f  18    29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f  21    29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f  20    31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f  21    30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f  16    26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ..   ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p
#
#     category    평균 test 결과
# 0    compact  23.5    pass
# 1    compact  25.0    pass
# 2    compact  25.5    pass
# ...

# %%
# 값을 세주는 함수
# .value_counts()
mpg_copy['test 결과'].value_counts()
# Out:
# test 결과
# pass    123
# fail    111
# Name: count, dtype: int64

# %%
# 평균 점수가 60점 이상인 사람 pass, fail
# pass, fail의 값도 확인

# %%
exam_copy['result'] = np.where(exam_copy['평균'] > 60, 'pass', 'fail')
exam_copy
# Out:
#      id  nclass  math  english  science    평균 result
# 0     1       1    52       98       50  66.7   pass
# 1     2       1    60       97       58  71.7   pass
# 2     3       1    44       86       78  69.3   pass
# 3     4       1    35       98       58  63.7   pass
# 4     5       1    27       80       65  57.3   fail
# ..  ...     ...   ...      ...      ...   ...    ...
# 95   96       5    58       98       65  73.7   pass
# 96   97       5    65       68       98  77.0   pass
# 97   98       5    80       78       90  82.7   pass
# 98   99       5    89       68       87  81.3   pass
# 99  100       5    78       83       58  73.0   pass
#
# [100 rows x 7 columns]

# %%
exam_copy['result'].value_counts()
# Out:
# result
# pass    85
# fail    15
# Name: count, dtype: int64

# %% [markdown]
# ### 컬럼 -- grade (등급)
# - 평균값이 25이상이면 A등급
# - 20이상 B등급
# - 그 외 C등급

# %%
mpg_grade = np.where(mpg_copy['평균'] >= 25, 'A등급', 
                     np.where(mpg_copy['평균']>=20, 'B등급','C등급'))

# %%
mpg_copy['grade'] = mpg_grade
mpg_copy
# Out:
#             제조사   model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f  18    29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f  21    29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f  20    31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f  21    30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f  16    26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ..   ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p
#
#     category    평균 test 결과 grade
# 0    compact  23.5    pass   B등급
# 1    compact  25.0    pass   A등급
# ...

# %%
mpg_copy['grade'].value_counts()
# Out:
# grade
# C등급    106
# B등급     85
# A등급     43
# Name: count, dtype: int64

# %% [markdown]
# ## apply()라는 함수
# - np.where의 조건식 복잡해지는 것을 간단하게 작성 할 수 있도록 하는 함수

# %%
# apply() 사용법

# 매개변수가 함수
# 함수를 만들어서 함수명만 작성 해주시면 됩니다.
def makeGrade(df): # 함수 실행시 조건이 될 시리즈가 필요! 매개변수로 df 작성
    grade = df['평균']
    
    if grade >= 25:
        return "A등급"
    elif grade >= 20:
        return "B등급"
    elif grade >= 15:
        return "C등급"
    else:
        return "F등급"

# %% [markdown]
# - axis = 0(행) or 1(열, 축)

# %%
# apply()
mpg_copy["grade2"] = mpg_copy.apply(makeGrade, axis=1)
mpg_copy
# Out:
#             제조사   model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f  18    29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f  21    29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f  20    31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f  21    30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f  16    26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ..   ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p
#
#     category    평균 test 결과 grade grade2
# 0    compact  23.5    pass   B등급    B등급
# ...

# %%
mpg_copy['grade2'].value_counts().sort_index()
# Out:
# grade2
# A등급    43
# B등급    85
# C등급    76
# F등급    30
# Name: count, dtype: int64

# %% [markdown]
# ### 불리언 인덱싱

# %%
#displ(배기량)이 4이하인 자동차와 5이상인 자동차중 고속도로 연비가 더 높은 차종 알아보기
mpg_4displ = mpg_copy[mpg_copy['displ']<=4]
mpg_4displ

# displ이 4이하인 자동차 구하기 - query 한수 사용해서
mpg_4 = mpg_copy.query("displ <= 4")
mpg_4
# Out:
#             제조사   model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f  18    29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f  21    29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f  20    31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f  21    30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f  16    26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ..   ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p
#
#     category    평균 test 결과 grade grade2
# 0    compact  23.5    pass   B등급    B등급
# ...

# %%
# 배기량이 5이상인 자동차 구하기 - query함수 사용
mpg_5 = mpg_copy.query('displ >= 5')
mpg_5
# Out:
#            제조사                   model  displ  year  실린더       trans drv  도시  \
# 18   chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r  14
# 19   chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r  11
# 20   chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r  14
# 21   chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r  13
# 22   chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r  12
# 23   chevrolet                corvette    5.7  1999    8  manual(m6)   r  16
# 24   chevrolet                corvette    5.7  1999    8    auto(l4)   r  15
# 25   chevrolet                corvette    6.2  2008    8  manual(m6)   r  16
# 26   chevrolet                corvette    6.2  2008    8    auto(s6)   r  15
# 27   chevrolet                corvette    7.0  2008    8  manual(m6)   r  15
# 28   chevrolet         k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4  14
# ...

# %%
mpg_4['고속도로'].mean()
# Out:
# 25.96319018404908

# %%
mpg_5['고속도로'].mean()
# Out:
# 18.07894736842105

# %%
# 아우디와 도요타 중 어느 제조회사의 도시연비 평균이 더 높은가?
mpg_audi = mpg_copy.query('제조사 == "audi"')
mpg_doyota = mpg_copy.query('제조사 == "toyota"')

# %%
mpg_audi['도시'].mean()
# Out:
# 17.61111111111111

# %%
mpg_doyota['도시'].mean()
# Out:
# 18.529411764705884

# %%
# 쉐보레 포드 혼다 자동차 고속도로 연비 평균
mpg_chevrolet = mpg_copy.query('제조사 == "chevrolet"')
mpg_ford = mpg_copy.query('제조사 == "ford"')
mpg_honda = mpg_copy.query('제조사 == "honda"')

# %%
mpg_chevrolet['고속도로'].mean()
# Out:
# 21.894736842105264

# %%
mpg_ford['고속도로'].mean()
# Out:
# 19.36

# %%
mpg_honda['고속도로'].mean()
# Out:
# 32.55555555555556

# %%
mpg_cfh = mpg_copy.query('제조사 == "chevrolet" or 제조사 == "ford" or 제조사 == "honda"')

# %%
mpg_cfh['고속도로'].mean()
# Out:
# 22.50943396226415

# %% [markdown]
# # 집단별(그룹별) 요약통계 확인
# - group by , agg
# - 보통 같이 사용

# %% [markdown]
# - group by

# %%
# group by("그룹화할 대상")
grouped_data = mpg_copy.groupby('제조사').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
# agg() - 다중집계작업
# agg(결과이름 = (컬럼명, 통계함수)) -- 컬럼명과 통계함수는 모두 문자열
# sum, mean, max, min, count

# %%
# 제조사별 도시연비 평균
mpg_copy.groupby('제조사').agg(city_mean=('도시','mean'))
# Out:
#             city_mean
# 제조사
# audi        17.611111
# chevrolet   15.000000
# dodge       13.135135
# ford        14.000000
# honda       24.444444
# hyundai     18.642857
# jeep        13.500000
# land rover  11.500000
# lincoln     11.333333
# mercury     13.250000
# nissan      18.076923
# pontiac     17.000000
# subaru      19.285714
# toyota      18.529412
# volkswagen  20.925926

# %%
mpg_copy.groupby('제조사').agg(city_max=('도시','max'))
# Out:
#             city_max
# 제조사
# audi              21
# chevrolet         22
# dodge             18
# ford              18
# honda             28
# hyundai           21
# jeep              17
# land rover        12
# lincoln           12
# mercury           14
# nissan            23
# pontiac           18
# subaru            21
# toyota            28
# volkswagen        35

# %%
mpg_copy.groupby('제조사').agg(city_min=('도시','min'))
# Out:
#             city_min
# 제조사
# audi              15
# chevrolet         11
# dodge              9
# ford              11
# honda             21
# hyundai           16
# jeep               9
# land rover        11
# lincoln           11
# mercury           13
# nissan            12
# pontiac           16
# subaru            18
# toyota            11
# volkswagen        16

# %%
mpg_copy.groupby('제조사').agg(city_count=('도시','count'))
# Out:
#             city_count
# 제조사
# audi                18
# chevrolet           19
# dodge               37
# ford                25
# honda                9
# hyundai             14
# jeep                 8
# land rover           4
# lincoln              3
# mercury              4
# nissan              13
# pontiac              5
# subaru              14
# toyota              34
# volkswagen          27

# %%
# 여러개 사용도 가능! - agg 사용해서
# 도시평균, 고속도로평균

# groupby로 제조사별로 묶기
# agg사용
mpg_copy.groupby('제조사').agg(city_mean = ('도시','mean'), high_mean = ('고속도로','mean'))
# Out:
#             city_mean  high_mean
# 제조사
# audi        17.611111  26.444444
# chevrolet   15.000000  21.894737
# dodge       13.135135  17.945946
# ford        14.000000  19.360000
# honda       24.444444  32.555556
# hyundai     18.642857  26.857143
# jeep        13.500000  17.625000
# land rover  11.500000  16.500000
# lincoln     11.333333  17.000000
# mercury     13.250000  18.000000
# nissan      18.076923  24.615385
# pontiac     17.000000  26.400000
# subaru      19.285714  25.571429
# toyota      18.529412  24.911765
# volkswagen  20.925926  29.222222

# %%
# 카테고리별 도시연비
# 카테고리 조사
mpg_copy['category'].value_counts()
# Out:
# category
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: count, dtype: int64

# %%
# 카테고리별로 groupby
# 도시 연비 평균
mpg_copy.groupby('category').agg(city_mean = ('도시','mean'))
# Out:
#             city_mean
# category
# 2seater     15.400000
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# pickup      13.000000
# subcompact  20.371429
# suv         13.500000

# %%
# 해당 곃과값 정렬
# error! -> 'by' argument
# by - 어떤 컬럼을 바탕으로 
mpg_copy.groupby('category').agg(city_mean = ('도시','mean')).sort_values(by = 'city_mean', ascending=False)
# Out:
#             city_mean
# category
# subcompact  20.371429
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# 2seater     15.400000
# suv         13.500000
# pickup      13.000000

# %%
# 제조사 별로 그룹을 묶은 후
# 제조사 별 등급(grade컬럼)을 나누기
# 예- audi A등급, B등급이 몇개인가?

# 그룹을 다시 나눌땐
# groupby시 [] 한번 더 감싸서 진행!
mpg_copy.groupby(['제조사','grade']).agg(grade_cnt = ('grade', 'count'))
# Out:
#                   grade_cnt
# 제조사        grade
# audi       A등급            3
#            B등급           13
#            C등급            2
# chevrolet  A등급            1
#            B등급            7
#            C등급           11
# dodge      B등급            4
#            C등급           33
# ford       B등급            4
#            C등급           21
# honda      A등급            9
# hyundai    A등급            2
#            B등급           12
# jeep       C등급            8
# land rover C등급            4
# lincoln    C등급            3
# mercury    C등급            4
# nissan     A등급            3
#            B등급            6
#            C등급            4
# pontiac    B등급            5
# subaru     B등급           14
# toyota     A등급           11
#            B등급            8
#            C등급           15
# volkswagen A등급           14
#            B등급           12
#            C등급            1

# %% [markdown]
# # merge(가로로 합치기)

# %%
mpg_copy['제조사'].unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %%
contry = pd.DataFrame({'제조사' : ['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep','land rover'
                                         , 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru','toyota', 'volkswagen'],
                      'contry' : ['독일','미국','미국','미국','일본','한국','미국','영국','미국','미국','일본','미국','일본','일본','독일']})
contry
# Out:
#            제조사 contry
# 0         audi     독일
# 1    chevrolet     미국
# 2        dodge     미국
# 3         ford     미국
# 4        honda     일본
# 5      hyundai     한국
# 6         jeep     미국
# 7   land rover     영국
# 8      lincoln     미국
# 9      mercury     미국
# 10      nissan     일본
# 11     pontiac     미국
# 12      subaru     일본
# 13      toyota     일본
# 14  volkswagen     독일

# %%
mpg_copy
# Out:
#             제조사   model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f  18    29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f  21    29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f  20    31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f  21    30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f  16    26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ..   ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p
#
#     category    평균 test 결과 grade grade2
# 0    compact  23.5    pass   B등급    B등급
# ...

# %%
mpg_c = pd.merge(mpg_copy, contry, how='left', on='제조사')
mpg_c
# Out:
#             제조사   model  displ  year  실린더       trans drv  도시  고속도로 연료  \
# 0          audi      a4    1.8  1999    4    auto(l5)   f  18    29  p
# 1          audi      a4    1.8  1999    4  manual(m5)   f  21    29  p
# 2          audi      a4    2.0  2008    4  manual(m6)   f  20    31  p
# 3          audi      a4    2.0  2008    4    auto(av)   f  21    30  p
# 4          audi      a4    2.8  1999    6    auto(l5)   f  16    26  p
# ..          ...     ...    ...   ...  ...         ...  ..  ..   ... ..
# 229  volkswagen  passat    2.0  2008    4    auto(s6)   f  19    28  p
# 230  volkswagen  passat    2.0  2008    4  manual(m6)   f  21    29  p
# 231  volkswagen  passat    2.8  1999    6    auto(l5)   f  16    26  p
# 232  volkswagen  passat    2.8  1999    6  manual(m5)   f  18    26  p
# 233  volkswagen  passat    3.6  2008    6    auto(s6)   f  17    26  p
#
#     category    평균 test 결과 grade grade2 contry
# 0    compact  23.5    pass   B등급    B등급     독일
# ...

# %%
# pd.merge()

# db - join inner, outer - left right

# how
# left = df1이 기준
# right = df2가 기준
# outer - 데이터를 모두 합치는데 만약에 df1이나 df2와 일치하지 않는 데이터가 존재 시
#       ㄴ nan값이 들어가게 됨
# test3로 확인

# inner - 교집합 부분만 표시 (일치하지 않는 데이터는 merge X)

# on - 기준이 될 컬럼
# pd.merge(df1, df2, how = '')

# %%
test1 = pd.DataFrame({'id':[1,2,3,4,5,6],'midterm':[60,80,70,90,85,80]})
test2 = pd.DataFrame({'id':[1,2,3,4,5],'final':[70,83,65,95,80]})

# %%
test3 = pd.merge(test1, test2, how = 'outer', on='id')
test3
# Out:
#    id  midterm  final
# 0   1       60   70.0
# 1   2       80   83.0
# 2   3       70   65.0
# 3   4       90   95.0
# 4   5       85   80.0
# 5   6       80    NaN

# %%
test4 = pd.merge(test1, test2, how = 'inner', on='id')
test4
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65
# 3   4       90     95
# 4   5       85     80

# %%
# 인덱스 번호의 중복을 없애고 이어서 작성
# 매개변수로 ignore_index = True 라고 작성
test4 = pd.concat([test1, test2], ignore )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[120], line 3
#       1 # 인덱스 번호의 중복을 없애고 이어서 작성
#       2 # 매개변수로 ignore_index = True 라고 작성
# ----> 3 test4 = pd.concat([test1, test2], ignore )
#
# NameError: name 'ignore' is not defined

# %% [markdown]
# # NaN이란 (not a number)
#  - 값이 없다
#
#  #### 결측치란?
#   - 누락된 값, 비어있는 값
#   - 수집과정에서 발생한 오류 때문에 포함 될 경우가 종종 발생
#   - 결측치 한다는 의미는 apply() 함수 적용하는데 어려움이 생기고
#   - 분석하는데 결과의 오류 발생
#   - 결측치 처리 하는 방법은 2가지 (삭제, 값을 채워주기)

# %%
df = pd.DataFrame({'gender':['m','f',np.nan,'m','f'],
                  'score':[5,4,3,4,np.nan]})
df
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0
# 4      f    NaN

# %%
# .dropna(subset = '기준이 되는 컬럼명')
# score의 값 중 nan값인 데이터만 drop하기
df.dropna(subset='score')
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0

# %%
# 내가 원하는 행만 삭제
# .drop(내가 삭제할 행(인덱스), axis = 0) : axis = 0(행), 1(열)
df.drop(2, axis = 0)
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0
# 4      f    NaN

# %%
# 여러개 열 삭제
df.drop([2,4], axis = 0)
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0

# %%
# 내가 원하는 열만 삭제
# .drop(내가 삭제할 컬럼명, axis = 1)   : axis = 0(행), 1(열)
df.drop('gender', axis = 1)
# Out:
#    score
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN

# %%
df.drop(['gender', 'score'], axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# # 주요 내용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### pandas 에서 자주 사용되는 함수들
# - .read_csv() : csv파일을 불러오기 위한 함수
# - .head() : 상위 5개의 데이터를 불러오는 기능 (소괄호 숫자 만큼 데이터 출력)
# - .tail() : 하위 5개의 데이터를 불러오는 기능 ( 위와 동일)
# - .info() : 해당 데이터의 정보 확인(예- 결측치, 컬럼의 이름, 수 확인)
# - .describe : 요약통계
# - .sort_values() : 값을 정렬(기본 - 오름차순, 내림차순 ascendong = False)
# - .sort_index() : 인덱스를 정렬 (위와 동일)
# - .value_counts() : 해당 value값의 개수를 확인
# - .copy() : 데이터 복사
# - .rename() : 컬럼명을 바꿀 때 사용
# - .set_index : 인덱스 설정
# - ★.apply() : 사용자 지정 함수를 만들어 보다 복잡한 처리를 도와주는 함수
#              ㄴ np.where()함수와 유사
# - .groupby() : 그룹별로 묶는 함수
# - .agg() : 요약 통계 함수
#
# - .merge() : 가로로 데이터 병합
# - .concat() : 세로로 데이터 병합
#
# ### 이 외에도 정말 많은 함수들이 존재
# - 해당 함수를 암기 하는게 아닌 사용법을 숙지하고

# %% [markdown]
# # 데이터 접근 : 인덱싱/슬라이싱
#
# ### 1. 인덱스 번호를 기준으로 접근
#  - []로 접근
#  - 슬라이싱의 경우에 : 기준으로 시작 범위와 끝 범위를 지정해주었습니다
#  - 행, 열을 데이터 접근시 .(comma)가 기준, 앞이 행, 뒤가 열
#  - loc, iloc 인덱서 존재
#  - loc, iloc의 경우 데이터 접근을 보다 쉽게 도와주는 역할
#   - loc 인덱스 값으로 접근, iloc 인덱스 번호로 접근이 가능
#
# ### 2. 조건을 기준으로 접근 (불리언 인덱싱)
#  - 조건에 따라 값을 가져오는 불리언 인덱싱이 존재
#   - 불리언 인덱싱 하는 방법 1
#     - []를 한번 더 감싼 후 조건을 작성 예) - mpg_copy.[mpg_copy['도시'] > 15]
#    - 불리언 인덱싱 하는 방법 2
#      - .query()함수 사용 : query함수 내 매개변수에 조건을 문자열로 작성
#        - 예) mpg_copy.query('mpg_copy[도시] > 15')

# %%
# concat - 새로운 병합
display(test1)
display(test2)
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85
# 5   6       80
#    id  final
# 0   1     70
# 1   2     83
# 2   3     65
# 3   4     95
# 4   5     80

# %% [markdown]
# ## NaN이란 (not a number)
#     - 값이 없다
#
# #### 결측치란?
#   - 누락된 값, 비어있는 값
#   - 수료과정에서 발생한 오류 때문에 포함될 경우가 종종 발생
#   - 결측치 한다는 의미는 aaply() 함수 적용하는데 어려움이 생기고 분석하는데 결과의 오류 발생
#   - 결측치 처리하는 방법은 2가지(삭제, 값을 채워주기)

# %%
df = pd.DataFrame({'gender':['m','f',np.nan,'m','f'],
                  'score':[5,4,3,4,np.nan]})
df
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0
# 4      f    NaN

# %%
# .dropna() - nan 값인 데이터를 모두 날려버립니다
df.dropna()
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0

# %%
#.dropna(subset = '기준이 되는 컬럼명')
# score의 값 중 nan값인 데이터만 drop하기
df.dropna(subset='score')
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 2    NaN    3.0
# 3      m    4.0

# %%
# 내가 원하는 행만 삭제
# .drop(내가 삭제할 행(인덱스), axis = 0 ) : axis=0(행),1(열)
df.drop(2, axis = 0)
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0
# 4      f    NaN

# %%
# 여러개 열 삭제
df.drop([2,4], axis = 0)
# Out:
#   gender  score
# 0      m    5.0
# 1      f    4.0
# 3      m    4.0

# %%
# 내가 원하는 열만 삭제
# .drop(내가 삭제할 컬럼명, axis = 1 )  : axis = 0(행), 1(열)
df.drop('gender', axis = 1)
# Out:
#    score
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN

# %%
df.drop(['gender','score'], axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# # seaborn 라이브러리
#  - 시각화, 그래프를 그리는 라이브러리
#  - matplotlib를 기초로 두고 있다!
#
#  - seaborn, matplotlib 2개의 시각화 라이브러리
#  - 뭐가 더 좋냐는 없고 선택사항
#  - seaborn의 장점 - 간단하게 작성이 가능
#  - matplotlib의 장점 - 고도화된 그래프를 그리는게 가능

# %%
import seaborn as sns

# %% [markdown]
# # 산점도 그래프
#  - 점이 흩어져 있는 그래프
#  - scatterplot

# %% [markdown]
# #### scatterplot(data = 데이터, x = 컬럼명, y = 컬럼명)

# %%
import matplotlib as plt
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
sns.scatterplot(data = mpg_copy, x = 'displ', y ='고속도로' )
# Out:
# <Axes: xlabel='displ', ylabel='고속도로'>

# %%
# scatterplot.set(xlim = 범위, ylim = 범위)
sns.scatterplot(data = mpg_copy, x = 'displ', y ='고속도로').set(xlim = [3,6])
# Out:
# [(3.0, 6.0)]

# %%
# hue = 색상 지정하는 컬럼 작성
sns.scatterplot(data = mpg_copy, x = 'displ', y='고속도로', hue = 'drv')
# Out:
# <Axes: xlabel='displ', ylabel='고속도로'>

# %%
# 구동 방식에 따른 고속도로 연비
# 1. 구동방식으로 묶어주기
mpg_copy.groupby('drv')
# 2. 통계 함수 사용해서 mean값 구하기
mpg_drv = mpg_copy.groupby('drv', as_index = False).agg(mean_hwy = ('고속도로', 'mean'))
mpg_drv
# Out:
#   drv   mean_hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %% [markdown]
# #### drv 4, f, r 구성
# #### 4- 사륜, f - front, r- rear
#
# # barplot(data=, x=, y=)

# %%
sns.barplot(data = mpg_drv, x = 'drv', y = 'mean_hwy')
# Out:
# <Axes: xlabel='drv', ylabel='mean_hwy'>

# %%
mpg_drv_sort = mpg_drv.sort_values('mean_hwy')
sns.barplot(data = mpg_drv, x = 'drv', y = 'mean_hwy')
# Out:
# <Axes: xlabel='drv', ylabel='mean_hwy'>

# %%
# 구동방식(drv) 데이터가 몇개씩 있는지 확인
# 1. 구동방식으로 묶어주기
mpg_copy.groupby('drv')
# 2. 통계 함수로 몇개인지 알기
mpg_drv_cnt = mpg_copy.groupby('drv', as_index=False).agg(drv_cnt = ('drv', 'count'))
mpg_drv_cnt
# Out:
#   drv  drv_cnt
# 0   4      103
# 1   f      106
# 2   r       25

# %%
sns.barplot(data = mpg_drv_cnt, x = 'drv', y = 'drv_cnt')
# Out:
# <Axes: xlabel='drv', ylabel='drv_cnt'>

# %% [markdown]
# #  countplot(data=, x=)

# %%
sns.countplot(data = mpg_copy, x = 'drv')
# Out:
# <Axes: xlabel='drv', ylabel='count'>

# %% [markdown]
# ###  y축은 작성이 안됨

# %%
sns.countplot(data = mpg_drv_cnt, x = 'drv', y = 'drv_cnt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 sns.countplot(data = mpg_drv_cnt, x = 'drv', y = 'drv_cnt')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2941, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2939     y = x
#    2940 elif x is not None and y is not None:
# -> 2941     raise ValueError("Cannot pass values for both `x` and `y`")
#    2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#
# ValueError: Cannot pass values for both `x` and `y`

# %% [markdown]
# ### 출력 순서 바꾸기

# %%
sns.countplot(data = mpg_copy, x = 'drv', order=['4', 'f', 'r'])
# Out:
# <Axes: xlabel='drv', ylabel='count'>

# %% [markdown]
# ### @실습 category가 suv인 차들의 제조사를 묶고
# ###    해당 제조사들의 도시 연비 평균을 구한 후 barplot으로 그려보시오

# %%
#1. 카테고리 suv인 차 가지고 오기
mpg_copy[mpg_copy['category'] == 'suv']

# 1.2 query()함수 사용
mpg_suv = mpg_copy.query('category == "suv"')
mpg_suv
# Out:
#            제조사                   model  displ  year  실린더       trans drv  도시  \
# 18   chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r  14
# 19   chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r  11
# 20   chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r  14
# 21   chevrolet      c1500 suburban 2wd    5.7  1999    8    auto(l4)   r  13
# 22   chevrolet      c1500 suburban 2wd    6.0  2008    8    auto(l4)   r  12
# ..         ...                     ...    ...   ...  ...         ...  ..  ..
# 176     toyota             4runner 4wd    3.4  1999    6  manual(m5)   4  15
# 177     toyota             4runner 4wd    4.0  2008    6    auto(l5)   4  16
# 178     toyota             4runner 4wd    4.7  2008    8    auto(l5)   4  14
# 198     toyota  land cruiser wagon 4wd    4.7  1999    8    auto(l4)   4  11
# 199     toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4  13
#
# ...

# %%
# 2. 제조사별로 묶기
mpg_suv.groupby('제조사').mean(True)
# Out:
#                displ         year       실린더         도시       고속도로         평균
# 제조사
# chevrolet   5.600000  2005.000000  8.000000  12.666667  17.111111  14.888889
# dodge       4.971429  2004.142857  7.714286  11.857143  16.000000  13.928571
# ford        4.555556  2002.000000  7.111111  12.888889  17.777778  15.333333
# jeep        4.575000  2005.750000  7.250000  13.500000  17.625000  15.562500
# land rover  4.300000  2003.500000  8.000000  11.500000  16.500000  14.000000
# lincoln     5.400000  2002.000000  8.000000  11.333333  17.000000  14.166667
# mercury     4.400000  2003.500000  7.000000  13.250000  18.000000  15.625000
# nissan      4.050000  2003.500000  6.500000  13.750000  18.000000  15.875000
# subaru      2.500000  2005.000000  4.000000  18.833333  25.000000  21.916667
# toyota      3.912500  2002.375000  6.250000  14.375000  18.250000  16.312500

# %%
# 3. 제조사들의 도시 연비 구하기
mpg_suv_city = mpg_suv.groupby('제조사', as_index = False).agg(city_mean=('도시', 'mean'))

# %%
# 4. barplot 그려보기
sns.barplot(data = mpg_suv_city, x = '제조사', y = 'city_mean')
# Out:
# <Axes: xlabel='제조사', ylabel='city_mean'>
