# %% [markdown]
# ### Matplotlib

# %% [markdown]
# #### 데이터를 한눈에 볼 수 있게 도표나 차트로 정리를 도와주는 라이브러리
# #### 시각화를 통해 데이터의 특징을 파악 가능
# #### 분석 결과를 상대방에 효과적으로 전달 가능

# %% [markdown]
# #### bar(count), scatter, line
#
# #### pie, histogram, boxplot

# %% [markdown]
# #### matplotlib에 존재하는 sub 패키지

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Line Plot

# %%
# line plot을 그리기 위해서는 x축 y축이 필요
x = np.arange(1,6) # x = [1, 2, 3, 4, 5]
np.random.seed(3)
y = np.random.randint(1, 10, size = 5) # y = [?,?,?,?,?]

print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
# plt.plot(x축, y축)

plt.plot(x, y)

# %%
# plt.plot(y축)
# -- x축은 자동으로 0~ y축의 개수 만큼 증가
plt.plot(y)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
plt.plot(x, y, ls = ":")

# %%
plt.plot(x, y, ls = ":", color = 'r', marker = 'D', mfc = 'b')
# plt.show()
# 만약 그래프가 안 나오면 plt.show() 사용해주기
# 쥬피터 노트북은 출력을 지원하는 개발환경이라 사용 안 해줘도 출력

# %%
# 한 화면에 여러개의 그래프를 출력

# 방법:plt.subplot(row, col, index)

plt.subplot(2, 2, 1)
plt.plot(x, y, ls = '-', c = 'b', marker = "D", ms = 10, mec = 'c', mew = 4, mfc ='y')

plt.subplot(2, 2, 2)
plt.plot(x, y, ls ='--', c = 'm', lw = 5)

plt.subplot(2, 2, 3)
plt.plot(x, y, ls = '-.')

plt.subplot(2, 2, 4)
plt.plot(x, y, ls = '-')

# %%
# 여러 그래프를 한 창에 그려지게(그래프 겹치기)

one_x = np.arange(1, 4) #[1, 2, 3]
one_y = np.array([1, 2, 3])
one_y2 = np.array([4, 5, 1])
one_y3 = np.array([3, 6, 2])

plt.plot(one_x, one_y)
plt.plot(one_x, one_y2)
plt.plot(one_x, one_y3)

# %%
# plt.show()
plt.plot(one_x, one_y)
plt.show()

plt.plot(one_x, one_y)
plt.plot(one_x, one_y2)
plt.plot(one_x, one_y3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# title - plt.title('타이틀 적기')
print(x)
print(y)

plt.title('Test title')
plt.plot(x, y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %% [markdown]
# ### title()

# %%
# title - plt.title('타이틀 적기')
print(x)
print(y)

plt.plot(x,y)
plt.title('Test title')
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]
# Text(0.5, 1.0, 'Test title')

# %% [markdown]
# ### grid()

# %%
# 격자눈금 함수
#plt.grid()

plt.plot(x,y)
plt.title('Test title')
plt.grid()

# %% [markdown]
# ### legend()

# %%
test_x = np.arange(1,6)
np.random.seed(5)
test_y = np.random.randint(1,10,size=5)

test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

print(test_x)
print(test_y)
print(test_x1)
print(test_y1)
# Out:
# [1 2 3 4 5]
# [4 7 7 1 9]
# [1 2 3 4 5]
# [5 1 2 1 2]

# %%
# legend() 사용방법
# plt.legend()
# 단, plt.plot을 그릴 때 해당 plot의 label 값을 지정해주어야 한다
#      ㄴ plt.plot(x, y, label = '라벨값 지정')

plt.plot(test_x, test_y, label = 'y')
plt.plot(test_x1, test_y1, label = 'y1')
plt.legend(loc = 'upper right')

# %% [markdown]
# ### xlabel(), ylabel()

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# plt.xlabel('이름')
# plt.ylabel('이름')

plt.plot(test_x, test_y, label = 'y')
plt.plot(test_x1, test_y1, label = 'y1')
plt.legend(loc = 'upper right')

plt.xlabel('x축')
plt.ylabel('y축')
# Out:
# Text(0, 0.5, 'y축')

# %% [markdown]
# ###  xlim(), ylim()

# %%
# xlim, ylim(시작, 끝)

plt.plot(test_x, test_y, label = 'y')
plt.plot(test_x1, test_y1, label = 'y1')
plt.legend(loc = 'upper right')

plt.xlabel('x축')
plt.ylabel('y축')

# x, y이 문자열인 경우 문자로 작성
plt.xlim(0, 10)
plt.ylim(0, 20)
# Out:
# (0.0, 20.0)

# %% [markdown]
# ### xticks, yticks

# %%
# 사용법 xticks, yticks(list, 배열)

plt.plot(test_x, test_y, label = 'y')
plt.plot(test_x, test_y1, label = 'y1')
plt.legend(loc = 'upper right')

plt.xlabel('x축')
plt.ylabel('y축')

plt.xticks(range(1,5))  # 1, 2, 3, 4, 5
plt.yticks(range(1,11,2))  #1, 3, 5, 7, 9
# Out:
# ([<matplotlib.axis.YTick at 0x1de1128dad0>,
#   <matplotlib.axis.YTick at 0x1de11284e90>,
#   <matplotlib.axis.YTick at 0x1de1126ec90>,
#   <matplotlib.axis.YTick at 0x1de112c4a50>,
#   <matplotlib.axis.YTick at 0x1de112c5890>],
#  [Text(0, 1, '1'),
#   Text(0, 3, '3'),
#   Text(0, 5, '5'),
#   Text(0, 7, '7'),
#   Text(0, 9, '9')])

# %% [markdown]
# ## 실습) 장래 인구 변동 데이터

# %%
# 컬럼 하나를 인덱스화
fu_pop = pd.read_csv('data/장래_인구변동_KOSIS.csv', encoding='euc-kr', index_col = '인구변동요인별')
fu_pop
# Out:
#            2020   2030   2040   2050   2060   2070
# 인구변동요인별
# 인구(천명)    51836  51199  50193  47359  42617  37656
# 출생아수(천명)    275    305    286    236    181    196
# 사망자수(천명)    308    408    527    680    741    702

# %%
# .columns - 해당 df 컬럼들을 가지고 올 수 있다
fu_pop.columns
fu_pop_x = list(fu_pop.columns)

print(fu_pop_x)
# Out:
# ['2020', '2030', '2040', '2050', '2060', '2070']

# %% [markdown]
# ### 연도별 출생아수

# %%
# 데이터 접근
fu_pop_y = fu_pop.iloc[1]
print(fu_pop_y)

fu_pop_y2 = fu_pop.iloc[2]
print(fu_pop_y2)
# Out:
# 2020    275
# 2030    305
# 2040    286
# 2050    236
# 2060    181
# 2070    196
# Name: 출생아수(천명), dtype: int64
# 2020    308
# 2030    408
# 2040    527
# 2050    680
# 2060    741
# 2070    702
# Name: 사망자수(천명), dtype: int64

# %%
plt.plot(fu_pop_x, fu_pop_y)

# %% [markdown]
# ##
#   - 출생아수, 사망자수 그래프

# %%
plt.plot(fu_pop_x, fu_pop_y, marker = '*', ms = 10, label = '출생아수(천명)')
plt.plot(fu_pop_x , fu_pop_y2 , marker='o',label = '사망자수(천명)')
plt.title('국가통계 요인별 장래 인구 동향')
plt.xlabel('연도')
plt.ylabel('사람수')
plt.legend()
plt.grid()

plt.yticks(range(150, 751 , 50))
# Out:
# ([<matplotlib.axis.YTick at 0x1de10fe3990>,
#   <matplotlib.axis.YTick at 0x1de11008550>,
#   <matplotlib.axis.YTick at 0x1de11009e90>,
#   <matplotlib.axis.YTick at 0x1de1105ba10>,
#   <matplotlib.axis.YTick at 0x1de11061e10>,
#   <matplotlib.axis.YTick at 0x1de112bb050>,
#   <matplotlib.axis.YTick at 0x1de110650d0>,
#   <matplotlib.axis.YTick at 0x1de11067110>,
#   <matplotlib.axis.YTick at 0x1de1106d3d0>,
#   <matplotlib.axis.YTick at 0x1de1106f3d0>,
#   <matplotlib.axis.YTick at 0x1de11071610>,
#   <matplotlib.axis.YTick at 0x1de0ffb2590>,
#   <matplotlib.axis.YTick at 0x1de11073b50>],
#  [Text(0, 150, '150'),
#   Text(0, 200, '200'),
#   Text(0, 250, '250'),
#   Text(0, 300, '300'),
#   Text(0, 350, '350'),
#   Text(0, 400, '400'),
#   Text(0, 450, '450'),
#   Text(0, 500, '500'),
#   Text(0, 550, '550'),
#   Text(0, 600, '600'),
#   Text(0, 650, '650'),
#   Text(0, 700, '700'),
#   Text(0, 750, '750')])

# %% [markdown]
# ### 그래프 이미지화

# %%
plt.plot(fu_pop_x, fu_pop_y, marker="*", ms = 10, label='출생아수')
plt.plot(fu_pop_x, fu_pop_y2, marker=".", ms = 10, label='사망자수')
plt.legend(loc = 'upper right')
plt.title('국가통계 요인별 장래 인구 동향')
plt.legend()
plt.grid()
plt.xlabel('연도')
plt.ylabel('사람수')

plt.yticks(range(150,751, 50))

# plt.savefig('경로/파일명.png', dpi = , bbox_inches)
# dpi = dots per inch : 해상도 설정
# bbox_inches = 저장할 부분의 공간을 지정 = tight 그림의 빈 공간을 최소화

plt.savefig('./test1.png', dpi = 600, bbox_inches = 'tight')

# %%
temp_data = pd.read_csv('data/온도데이터(1971-2023).csv', encoding='euc-kr', skiprows=range(0,7))

# %%
temp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19155 entries, 0 to 19154
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       19155 non-null  object
#  1   지점       19155 non-null  int64
#  2   평균기온(℃)  19155 non-null  float64
#  3   최저기온(℃)  19154 non-null  float64
#  4   최고기온(℃)  19154 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 748.4+ KB

# %%
temp_data[temp_data.iloc[:,4].isna()]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 1019  \t1973-10-16  156     11.9      NaN      NaN

# %% [markdown]
# ## 본인 생일의 연도별 최고, 최저 기온

# %%
temp_data.iloc[1018, :]
# Out:
# 날짜         \t1973-10-15
# 지점                  156
# 평균기온(℃)            11.6
# 최저기온(℃)             3.8
# 최고기온(℃)            20.0
# Name: 1018, dtype: object

# %%
# 평균 온도 - lineplot으로 

temp_data['평균기온(℃)']
# Out:
# 0         2.0
# 1        -0.2
# 2        -0.7
# 3        -6.4
# 4        -8.4
#          ...
# 19150    21.7
# 19151    22.5
# 19152    24.2
# 19153    24.1
# 19154    24.5
# Name: 평균기온(℃), Length: 19155, dtype: float64

# %%
plt.plot(temp_data['평균기온(℃)'])
# Out:
# C:\Users\smhrd\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\smhrd\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
temp_data.head()
# Out:
#              날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  \t1971-01-01  156      2.0     -0.6      6.3
# 1  \t1971-01-02  156     -0.2     -4.0      5.0
# 2  \t1971-01-03  156     -0.7     -5.2      5.3
# 3  \t1971-01-04  156     -6.4     -9.3     -0.9
# 4  \t1971-01-05  156     -8.4    -13.9     -4.7

# %%
# 파생변수 새로운 컬럼 월-일
temp_data['날짜'].str[-5:]
# Out:
# 0        01-01
# 1        01-02
# 2        01-03
# 3        01-04
# 4        01-05
#          ...
# 19150    06-07
# 19151    06-08
# 19152    06-09
# 19153    06-10
# 19154    06-11
# Name: 날짜, Length: 19155, dtype: object

# %%
temp_data['날짜'].str[-5:]
# Out:
# 0        01-01
# 1        01-02
# 2        01-03
# 3        01-04
# 4        01-05
#          ...
# 19150    06-07
# 19151    06-08
# 19152    06-09
# 19153    06-10
# 19154    06-11
# Name: 날짜, Length: 19155, dtype: object

# %%
temp_data['월일'] = temp_data['날짜'].str[-5:]
temp_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05
# ...             ...  ...      ...      ...      ...    ...
# 19150  \t2023-06-07  156     21.7     16.4     28.6  06-07
# 19151  \t2023-06-08  156     22.5     18.1     29.0  06-08
# 19152  \t2023-06-09  156     24.2     19.2     30.5  06-09
# 19153  \t2023-06-10  156     24.1     20.8     30.9  06-10
# 19154  \t2023-06-11  156     24.5     21.4     30.7  06-11
#
# [19155 rows x 6 columns]

# %%
# 1971/1/1 ~
# 본인 생일만 검색
birth_data = temp_data.query("월일 == '08-12'")
birth_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 223    \t1971-08-12  156     25.8     22.0     30.4  08-12
# 589    \t1972-08-12  156     23.1     16.8     29.4  08-12
# 954    \t1973-08-12  156     27.5     23.0     32.8  08-12
# 1319   \t1974-08-12  156     27.3     22.0     32.5  08-12
# 1684   \t1975-08-12  156     27.2     22.6     32.6  08-12
# 2050   \t1976-08-12  156     28.2     24.5     32.7  08-12
# 2415   \t1977-08-12  156     23.1     18.3     29.6  08-12
# 2780   \t1978-08-12  156     27.2     24.6     30.9  08-12
# 3145   \t1979-08-12  156     27.5     21.8     33.8  08-12
# 3511   \t1980-08-12  156     22.9     20.4     26.4  08-12
# 3876   \t1981-08-12  156     24.8     19.2     30.2  08-12
# 4241   \t1982-08-12  156     27.1     23.6     30.7  08-12
# 4606   \t1983-08-12  156     26.9     23.0     33.2  08-12
# 4972   \t1984-08-12  156     29.0     22.9     35.2  08-12
# 5337   \t1985-08-12  156     26.4     23.9     29.3  08-12
# 5702   \t1986-08-12  156     23.9     20.2     29.7  08-12
# 6067   \t1987-08-12  156     24.4     19.4     30.8  08-12
# 6433   \t1988-08-12  156     27.7     24.3     32.0  08-12
# 6798   \t1989-08-12  156     26.2     25.4     30.6  08-12
# 7163   \t1990-08-12  156     27.6     22.1     35.2  08-12
# 7528   \t1991-08-12  156     25.3     22.2     28.9  08-12
# 7894   \t1992-08-12  156     25.1     22.7     27.8  08-12
# 8259   \t1993-08-12  156     23.9     22.8     26.3  08-12
# 8624   \t1994-08-12  156     29.0     24.9     34.2  08-12
# 8989   \t1995-08-12  156     28.6     25.7     33.0  08-12
# 9355   \t1996-08-12  156     28.8     24.0     34.9  08-12
# 9720   \t1997-08-12  156     25.7     22.7     30.4  08-12
# 10085  \t1998-08-12  156     28.6     26.9     32.4  08-12
# 10450  \t1999-08-12  156     28.0     23.8     32.1  08-12
# 10816  \t2000-08-12  156     28.5     23.8     33.9  08-12
# 11181  \t2001-08-12  156     22.8     18.7     28.3  08-12
# 11546  \t2002-08-12  156     21.1     20.6     22.2  08-12
# 11911  \t2003-08-12  156     23.7     19.5     28.5  08-12
# 12277  \t2004-08-12  156     29.0     24.2     34.7  08-12
# 12642  \t2005-08-12  156     28.6     25.9     32.9  08-12
# 13007  \t2006-08-12  156     27.9     25.2     32.0  08-12
# 13372  \t2007-08-12  156     26.0     24.7     28.7  08-12
# 13738  \t2008-08-12  156     27.4     24.8     31.8  08-12
# 14103  \t2009-08-12  156     25.9     24.2     27.8  08-12
# 14468  \t2010-08-12  156     28.5     24.1     33.4  08-12
# 14833  \t2011-08-12  156     26.6     24.0     31.1  08-12
# 15199  \t2012-08-12  156     28.5     24.5     32.6  08-12
# 15564  \t2013-08-12  156     29.8     25.6     35.4  08-12
# 15929  \t2014-08-12  156     25.3     19.5     31.3  08-12
# 16294  \t2015-08-12  156     23.8     19.7     28.6  08-12
# 16660  \t2016-08-12  156     30.6     25.9     37.2  08-12
# 17025  \t2017-08-12  156     27.2     24.6     31.5  08-12
# 17390  \t2018-08-12  156     29.3     25.1     34.1  08-12
# 17755  \t2019-08-12  156     27.9     26.1     30.4  08-12
# 18121  \t2020-08-12  156     27.6     25.6     31.2  08-12
# 18486  \t2021-08-12  156     26.3     22.8     30.3  08-12
# 18851  \t2022-08-12  156     27.9     25.6     32.0  08-12

# %%
plt.title('내 생일 평균 온도')
plt.plot(range(1971,2023), birth_data['평균기온(℃)'])

# %% [markdown]
# ## 실습) 내 생일 최저, 최고 기온 시각화

# %%
plt.plot(range(1971,2023), birth_data['최저기온(℃)'], label = "최저기온")
plt.plot(range(1971,2023), birth_data['최고기온(℃)'], label = "최고기온")
plt.legend(loc = 'upper right')
plt.title('birth_high_low_tdata')
# Out:
# Text(0.5, 1.0, 'birth_high_low_tdata')

# %% [markdown]
# ## ========================================================

# %% [markdown]
# ## 히스토그램
#   - 데이터의 빈도를 막대그래프형식으로 표시

# %%
# 주사위를 100번 던져서 나오는 수들의 분포를 히스토그램으로 그려보기
np.random.seed(3)
a = np.random.randint(1,7, size = 100)
a
# Out:
# array([3, 1, 2, 4, 1, 1, 1, 6, 6, 4, 3, 4, 2, 2, 3, 6, 1, 5, 5, 6, 1, 3,
#        2, 3, 3, 3, 5, 2, 4, 3, 6, 1, 2, 6, 3, 1, 4, 1, 4, 2, 4, 1, 6, 5,
#        2, 6, 5, 5, 1, 1, 2, 3, 5, 6, 1, 1, 6, 6, 2, 2, 2, 6, 6, 3, 4, 5,
#        5, 4, 4, 1, 1, 1, 1, 3, 3, 4, 1, 6, 6, 1, 6, 2, 5, 2, 5, 3, 3, 5,
#        5, 3, 1, 5, 1, 4, 3, 1, 5, 4, 2, 6])

# %%
np.unique(a, return_counts=True)
# Out:
# (array([1, 2, 3, 4, 5, 6]), array([23, 15, 17, 13, 15, 17], dtype=int64))

# %% [markdown]
# ## plt.hist()

# %%
plt.hist(a, bins = 6) # bin 매개변수 - 해당 히스토그램을 몇 개로 나눌 것인지
# Out:
# (array([23., 15., 17., 13., 15., 17.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <BarContainer object of 6 artists>)

# %%
temp_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05
# ...             ...  ...      ...      ...      ...    ...
# 19150  \t2023-06-07  156     21.7     16.4     28.6  06-07
# 19151  \t2023-06-08  156     22.5     18.1     29.0  06-08
# 19152  \t2023-06-09  156     24.2     19.2     30.5  06-09
# 19153  \t2023-06-10  156     24.1     20.8     30.9  06-10
# 19154  \t2023-06-11  156     24.5     21.4     30.7  06-11
#
# [19155 rows x 6 columns]

# %%
# 월의 최고 기온을 히스토그램

# 파생변수
temp_data['월'] = temp_data['월일'].str[:2]
temp_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01  01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02  01
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03  01
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04  01
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05  01
# ...             ...  ...      ...      ...      ...    ...  ..
# 19150  \t2023-06-07  156     21.7     16.4     28.6  06-07  06
# 19151  \t2023-06-08  156     22.5     18.1     29.0  06-08  06
# 19152  \t2023-06-09  156     24.2     19.2     30.5  06-09  06
# 19153  \t2023-06-10  156     24.1     20.8     30.9  06-10  06
# 19154  \t2023-06-11  156     24.5     21.4     30.7  06-11  06
#
# [19155 rows x 7 columns]

# %%
# 12월의 최고 기온
month_temp = temp_data.query('월 == "12"')
month_temp
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 334    \t1971-12-01  156      5.5      1.7      9.9  12-01  12
# 335    \t1971-12-02  156      9.1      4.6     13.2  12-02  12
# 336    \t1971-12-03  156      6.9      1.8     10.2  12-03  12
# 337    \t1971-12-04  156      5.8     -1.8     12.8  12-04  12
# 338    \t1971-12-05  156      7.0      1.4     13.0  12-05  12
# ...             ...  ...      ...      ...      ...    ...  ..
# 18988  \t2022-12-27  156      0.3     -4.2      5.7  12-27  12
# 18989  \t2022-12-28  156     -0.2     -3.4      5.2  12-28  12
# 18990  \t2022-12-29  156      0.7     -3.7      5.1  12-29  12
# 18991  \t2022-12-30  156      1.0     -2.2      5.4  12-30  12
# 18992  \t2022-12-31  156      1.4     -1.5      6.0  12-31  12
#
# [1612 rows x 7 columns]

# %%
plt.hist(month_temp['최저기온(℃)'], bins = 100, color = 'b', alpha = 0.5, label="최저기온")  # alpha 투명도 : 소수점
plt.hist(month_temp['최고기온(℃)'], bins = 100, color = 'r', alpha = 0.5, label="최고기온")  # alpha 투명도 : 소수점
plt.legend()
plt.show()
# Out:
# C:\Users\smhrd\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(1)
tmp_data = np.random.randint(10,size = 10)
# print(tmp_data)
tmp_data= np.append(tmp_data, 20)
# print(tmp_data)
plt.boxplot(tmp_data, labels=['데이터명'])
plt.show()

# %%
temp_data
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01  01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02  01
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03  01
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04  01
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05  01
# ...             ...  ...      ...      ...      ...    ...  ..
# 19150  \t2023-06-07  156     21.7     16.4     28.6  06-07  06
# 19151  \t2023-06-08  156     22.5     18.1     29.0  06-08  06
# 19152  \t2023-06-09  156     24.2     19.2     30.5  06-09  06
# 19153  \t2023-06-10  156     24.1     20.8     30.9  06-10  06
# 19154  \t2023-06-11  156     24.5     21.4     30.7  06-11  06
#
# [19155 rows x 7 columns]

# %%
temp_month = temp_data.query('월 == "01"')
temp_month
# Out:
#                  날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0      \t1971-01-01  156      2.0     -0.6      6.3  01-01  01
# 1      \t1971-01-02  156     -0.2     -4.0      5.0  01-02  01
# 2      \t1971-01-03  156     -0.7     -5.2      5.3  01-03  01
# 3      \t1971-01-04  156     -6.4     -9.3     -0.9  01-04  01
# 4      \t1971-01-05  156     -8.4    -13.9     -4.7  01-05  01
# ...             ...  ...      ...      ...      ...    ...  ..
# 19019  \t2023-01-27  156     -2.8     -4.5     -0.3  01-27  01
# 19020  \t2023-01-28  156     -2.8     -7.7      1.9  01-28  01
# 19021  \t2023-01-29  156      1.3     -3.5      6.2  01-29  01
# 19022  \t2023-01-30  156      1.8     -1.3      6.3  01-30  01
# 19023  \t2023-01-31  156      3.7     -3.7     11.5  01-31  01
#
# [1643 rows x 7 columns]

# %% [markdown]
# ## 1월의 평균 기온

# %%
plt.boxplot(temp_month['평균기온(℃)'],labels=['평균기온(℃)'])
plt.show()
# Out:
# C:\Users\smhrd\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 2D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(6)
tmp_data2 = np.random.randint(1,50,size=(10,2))
print(tmp_data2)
plt.boxplot(tmp_data2, labels = ['1열','2열'])
plt.show()
# Out:
# [[11 10]
#  [36 21]
#  [43 46]
#  [16 43]
#  [17 26]
#  [ 2 12]
#  [14 27]
#  [48 34]
#  [45 47]
#  [ 5 34]]

# %% [markdown]
# ## 최고기온, 최저기온

# %%
plt.boxplot(temp_month[['최저기온(℃)', '최고기온(℃)']], labels=['최저기온','최고기온'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1de14246490>,
#   <matplotlib.lines.Line2D at 0x1de142249d0>,
#   <matplotlib.lines.Line2D at 0x1de1423a010>,
#   <matplotlib.lines.Line2D at 0x1de1423bc50>],
#  'caps': [<matplotlib.lines.Line2D at 0x1de14225950>,
#   <matplotlib.lines.Line2D at 0x1de142268d0>,
#   <matplotlib.lines.Line2D at 0x1de1423a090>,
#   <matplotlib.lines.Line2D at 0x1de142381d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1de14205f10>,
#   <matplotlib.lines.Line2D at 0x1de14226bd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1de14224c10>,
#   <matplotlib.lines.Line2D at 0x1de14239990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1de14282b50>,
#   <matplotlib.lines.Line2D at 0x1de1419e8d0>],
#  'means': []}
# C:\Users\smhrd\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\smhrd\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Barplot

# %%
np.random.seed(6)
bar_x = np.arange(1,4)
bar_y = np.random.randint(50,100, size = 3)

#plt.bar(x,y)
plt.bar(bar_x, bar_y)
# Out:
# <BarContainer object of 3 artists>

# %%
# barplot 색깔
plt.bar(bar_x, bar_y, color = {'royalblue','midnightblue','lightskyblue'})
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## 그래프 색상 함수

# %%
# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors  doc제공 코드
import math
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %% [markdown]
# ## barplot 안에 글씨 넣어보기

# %%
print(bar_x)
print(bar_y)
# Out:
# [1 2 3]
# [60 59 85]

# %%
bar_x[0]
# Out:
# 1

# %%
# x, y, s
# bar 하나에 작성이 되는 것 - 요소 하나하나 작성
# ha = hoziztal alignment
# va = vertical alignment
plt.bar(bar_x,bar_y)
plt.text(bar_x[0], bar_y[0], bar_y[0], fontdict={'color': 'red', 'size' :14},ha  = 'right',va = 'center')
plt.show()

# %%
# barplot 색깔
plt.bar(bar_x, bar_y, color = ['royalblue','midnightblue','lightskyblue'])

# plt.text(bar_x[0], bar_y[0], bar_y[0], fontdict={'color': 'black', 'size' :14}, ha = 'center', va = '')
# plt.text(bar_x[0], bar_y[0], bar_y[0], fontdict={'color': 'black', 'size' :14}, ha = 'center', va = '')

for i in range(len(bar_x)): #range(3) -- 0~2
    plt.text(bar_x[i], bar_y[i], bar_y[i], fontdict={'color': 'black', 'size' :14}, ha = 'center', va = 'center')

plt.show()

# %%
sidoGender = pd.read_csv('data/시도_성별_경제활동인구_총괄_KOSIS_2022.csv', encoding='euc-kr')
sidoGender
# Out:
#    행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0     서울특별시  남자          4007         2849      2760        89          1158
# 1     서울특별시  여자          4440         2418      2347        72          2022
# 2     부산광역시  남자          1406          973       946        27           433
# 3     부산광역시  여자          1528          768       745        23           760
# 4     대구광역시  남자          1001          708       691        17           294
# 5     대구광역시  여자          1071          556       543        13           515
# 6     인천광역시  남자          1279          955       928        27           324
# 7     인천광역시  여자          1309          732       717        15           577
# 8     광주광역시  남자           623          434       423        10           190
# 9     광주광역시  여자           656          346       339         8           309
# 10    대전광역시  남자           635          466       461         5           169
# 11    대전광역시  여자           653          353       346         7           300
# 12    울산광역시  남자           489          360       349        11           129
# 13    울산광역시  여자           466          230       224         6           236
# 14  세종특별자치시  남자           156          120       119         2            36
# 15  세종특별자치시  여자           158           85        83         1            74
# 16      경기도  남자          5944         4560      4459       101          1384
# 17      경기도  여자          5981         3283      3199        84          2697
# 18      강원도  남자           651          465       454        11           186
# 19      강원도  여자           675          403       393        10           272
# 20     충청북도  남자           722          555       543        12           167
# 21     충청북도  여자           708          402       399         3           306
# 22     충청남도  남자           975          754       740        14           221
# 23     충청남도  여자           938          550       542         8           388
# 24     전라북도  남자           766          548       540         9           218
# 25     전라북도  여자           790          453       446         7           337
# 26     전라남도  남자           762          580       571         8           182
# 27     전라남도  여자           763          460       454         6           302
# 28     경상북도  남자          1166          875       854        21           290
# 29     경상북도  여자          1161          652       638        14           509
# 30     경상남도  남자          1427         1036      1009        27           391
# 31     경상남도  여자          1421          760       740        20           661
# 32  제주특별자치도  남자           285          227       221         5            59
# 33  제주특별자치도  여자           291          197       195         2            94
#
#     경제활동참가율(％)  고용률(%)  실업률(%)
# 0         71.1    68.9     3.1
# 1         54.5     NaN     3.0
# 2         69.2    67.3     2.7
# 3         50.3    48.8     3.0
# 4         70.6    69.0     2.3
# 5         51.9     NaN     NaN
# 6         74.7     NaN     NaN
# 7         55.9     NaN     2.0
# 8         69.6     NaN     2.4
# 9         52.8     NaN     2.3
# 10        73.4     NaN     1.0
# 11        54.0     NaN     2.0
# 12        73.7    71.3     3.2
# 13        49.4    48.2     2.4
# 14        77.0    75.9     1.4
# 15        53.4    52.5     1.7
# 16        76.7    75.0     2.2
# 17        54.9     NaN     2.6
# 18        71.4    69.7     2.3
# 19        59.7    58.2     2.5
# 20        76.9    75.2     2.2
# 21        56.7    56.4     0.6
# 22        77.3    76.0     NaN
# 23        58.6    57.8     NaN
# 24        71.5    70.4     NaN
# 25        57.3    56.4     1.5
# 26        76.1    75.0     1.4
# 27        60.4     NaN     1.3
# 28        75.1    73.3     2.4
# 29        56.2    55.0     2.1
# 30        72.6    70.7     2.6
# 31        53.5    52.0     NaN
# 32        79.4    77.6     2.3
# 33        67.6    66.9     1.0

# %%
sidoGender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        24 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
# 고용률 전처리

# 고용률 = 취업자 / 15세이상 인구

# sidoGender.query('고용률(%).isna()')
# sidoGender[sidoGender['고용률(%)'].notna()]
sidoGender[sidoGender['고용률(%)'].isna()]
# Out:
#    행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 1     서울특별시  여자          4440         2418      2347        72          2022
# 5     대구광역시  여자          1071          556       543        13           515
# 6     인천광역시  남자          1279          955       928        27           324
# 7     인천광역시  여자          1309          732       717        15           577
# 8     광주광역시  남자           623          434       423        10           190
# 9     광주광역시  여자           656          346       339         8           309
# 10    대전광역시  남자           635          466       461         5           169
# 11    대전광역시  여자           653          353       346         7           300
# 17      경기도  여자          5981         3283      3199        84          2697
# 27     전라남도  여자           763          460       454         6           302
#
#     경제활동참가율(％)  고용률(%)  실업률(%)
# 1         54.5     NaN     3.0
# 5         51.9     NaN     NaN
# 6         74.7     NaN     NaN
# 7         55.9     NaN     2.0
# 8         69.6     NaN     2.4
# 9         52.8     NaN     2.3
# 10        73.4     NaN     1.0
# 11        54.0     NaN     2.0
# 17        54.9     NaN     2.6
# 27        60.4     NaN     1.3

# %%
temp_goyong = sidoGender['취업자 (천명)']/sidoGender['15세이상인구 (천명)']
# round() 실수의 자릿수 (범위) 지정
# round(data, 숫자)
temp_goyong = round(temp_goyong, 3) * 100
temp_goyong
# Out:
# 0     68.9
# 1     52.9
# 2     67.3
# 3     48.8
# 4     69.0
# 5     50.7
# 6     72.6
# 7     54.8
# 8     67.9
# 9     51.7
# 10    72.6
# 11    53.0
# 12    71.4
# 13    48.1
# 14    76.3
# 15    52.5
# 16    75.0
# 17    53.5
# 18    69.7
# 19    58.2
# 20    75.2
# 21    56.4
# 22    75.9
# 23    57.8
# 24    70.5
# 25    56.5
# 26    74.9
# 27    59.5
# 28    73.2
# 29    55.0
# 30    70.7
# 31    52.1
# 32    77.5
# 33    67.0
# dtype: float64

# %%
sidoGender['고용률(%)'] = temp_goyong
sidoGender[sidoGender['고용률(%)'].notna()]
# Out:
#    행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0     서울특별시  남자          4007         2849      2760        89          1158
# 1     서울특별시  여자          4440         2418      2347        72          2022
# 2     부산광역시  남자          1406          973       946        27           433
# 3     부산광역시  여자          1528          768       745        23           760
# 4     대구광역시  남자          1001          708       691        17           294
# 5     대구광역시  여자          1071          556       543        13           515
# 6     인천광역시  남자          1279          955       928        27           324
# 7     인천광역시  여자          1309          732       717        15           577
# 8     광주광역시  남자           623          434       423        10           190
# 9     광주광역시  여자           656          346       339         8           309
# 10    대전광역시  남자           635          466       461         5           169
# 11    대전광역시  여자           653          353       346         7           300
# 12    울산광역시  남자           489          360       349        11           129
# 13    울산광역시  여자           466          230       224         6           236
# 14  세종특별자치시  남자           156          120       119         2            36
# 15  세종특별자치시  여자           158           85        83         1            74
# 16      경기도  남자          5944         4560      4459       101          1384
# 17      경기도  여자          5981         3283      3199        84          2697
# 18      강원도  남자           651          465       454        11           186
# 19      강원도  여자           675          403       393        10           272
# 20     충청북도  남자           722          555       543        12           167
# 21     충청북도  여자           708          402       399         3           306
# 22     충청남도  남자           975          754       740        14           221
# 23     충청남도  여자           938          550       542         8           388
# 24     전라북도  남자           766          548       540         9           218
# 25     전라북도  여자           790          453       446         7           337
# 26     전라남도  남자           762          580       571         8           182
# 27     전라남도  여자           763          460       454         6           302
# 28     경상북도  남자          1166          875       854        21           290
# 29     경상북도  여자          1161          652       638        14           509
# 30     경상남도  남자          1427         1036      1009        27           391
# 31     경상남도  여자          1421          760       740        20           661
# 32  제주특별자치도  남자           285          227       221         5            59
# 33  제주특별자치도  여자           291          197       195         2            94
#
#     경제활동참가율(％)  고용률(%)  실업률(%)
# 0         71.1    68.9     3.1
# 1         54.5    52.9     3.0
# 2         69.2    67.3     2.7
# 3         50.3    48.8     3.0
# 4         70.6    69.0     2.3
# 5         51.9    50.7     NaN
# 6         74.7    72.6     NaN
# 7         55.9    54.8     2.0
# 8         69.6    67.9     2.4
# 9         52.8    51.7     2.3
# 10        73.4    72.6     1.0
# 11        54.0    53.0     2.0
# 12        73.7    71.4     3.2
# 13        49.4    48.1     2.4
# 14        77.0    76.3     1.4
# 15        53.4    52.5     1.7
# 16        76.7    75.0     2.2
# 17        54.9    53.5     2.6
# 18        71.4    69.7     2.3
# 19        59.7    58.2     2.5
# 20        76.9    75.2     2.2
# 21        56.7    56.4     0.6
# 22        77.3    75.9     NaN
# 23        58.6    57.8     NaN
# 24        71.5    70.5     NaN
# 25        57.3    56.5     1.5
# 26        76.1    74.9     1.4
# 27        60.4    59.5     1.3
# 28        75.1    73.2     2.4
# 29        56.2    55.0     2.1
# 30        72.6    70.7     2.6
# 31        53.5    52.1     NaN
# 32        79.4    77.5     2.3
# 33        67.6    67.0     1.0

# %%
# 실업률 전처리
# 실업률 = 실업자/경제활동인구

temp_unemp = sidoGender['실업자 (천명)']/sidoGender['경제활동인구 (천명)']
temp_unemp = round(temp_unemp, 3) * 100
temp_unemp
# Out:
# 0     3.1
# 1     3.0
# 2     2.8
# 3     3.0
# 4     2.4
# 5     2.3
# 6     2.8
# 7     2.0
# 8     2.3
# 9     2.3
# 10    1.1
# 11    2.0
# 12    3.1
# 13    2.6
# 14    1.7
# 15    1.2
# 16    2.2
# 17    2.6
# 18    2.4
# 19    2.5
# 20    2.2
# 21    0.7
# 22    1.9
# 23    1.5
# 24    1.6
# 25    1.5
# 26    1.4
# 27    1.3
# 28    2.4
# 29    2.1
# 30    2.6
# 31    2.6
# 32    2.2
# 33    1.0
# dtype: float64

# %%
sidoGender['실업률(%)'] = temp_unemp
sidoGender[sidoGender['실업률(%)'].isna()]
# Out:
# Empty DataFrame
# Columns: [행정구역(시도), 성별, 15세이상인구 (천명), 경제활동인구 (천명), 취업자 (천명), 실업자 (천명), 비경제활동인구 (천명), 경제활동참가율(％), 고용률(%), 실업률(%)]
# Index: []

# %%
# 시 도별 고용률 평균 시각화
goyong_rate = sidoGender[['행정구역(시도)', '고용률(%)']].groupby('행정구역(시도)', as_index=False).mean(True)
goyong_rate.sort_values(by = '고용률(%)', ascending=False).head(5)
# Out:
#    행정구역(시도)  고용률(%)
# 14  제주특별자치도   72.25
# 12     전라남도   67.20
# 15     충청남도   66.85
# 16     충청북도   65.80
# 9   세종특별자치시   64.40

# %%
# 그래프의 사이즈
# plt.figure(figsize= (가로, 세로)) # 단위는 인치
plt.figure(figsize= (10,4))

plt.bar(goyong_rate['행정구역(시도)'], goyong_rate['고용률(%)'])
plt.title('시도별 고용률 평균')
plt.xlabel('행정구역(시도)')
plt.ylabel('고용률(%)')

#xticks 기울기
plt.xticks(rotation = 45)
plt.ylim(50,80)
plt.show()

# %%
plt.barh(goyong_rate['행정구역(시도)'], goyong_rate['고용률(%)'])
plt.xlim(50,80)
plt.show()

# %%
# seaborn 으로 그리기 - 고용률
plt.figure(figsize=(10,4))
sns.barplot(data = goyong_rate, x = goyong_rate['행정구역(시도)'], y= goyong_rate['고용률(%)'])
plt.xticks(rotation = 45)
plt.grid()
plt.show()

# %% [markdown]
# ## 실습) 시도별 남자의 실업률 막대그래프

# %%
man = sidoGender.query('성별 == "남자"')
man_unemp = man[['행정구역(시도)', '실업률(%)']]
man_unemp
# Out:
#    행정구역(시도)  실업률(%)
# 0     서울특별시     3.1
# 2     부산광역시     2.8
# 4     대구광역시     2.4
# 6     인천광역시     2.8
# 8     광주광역시     2.3
# 10    대전광역시     1.1
# 12    울산광역시     3.1
# 14  세종특별자치시     1.7
# 16      경기도     2.2
# 18      강원도     2.4
# 20     충청북도     2.2
# 22     충청남도     1.9
# 24     전라북도     1.6
# 26     전라남도     1.4
# 28     경상북도     2.4
# 30     경상남도     2.6
# 32  제주특별자치도     2.2

# %%
plt.figure(figsize=(15,8))
sns.barplot(data = man_unemp, x = man_unemp['행정구역(시도)'], y=man_unemp['실업률(%)'])
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Scatter

# %%
np.random.seed(2)
x = np.arange(1,4)
y = np.random.rand(3)
print(x,y)

# 매개변수 추가하기
# s (scale) = [요소의 개수만큼 크기 숫자를 작성]
plt.scatter(x, y, s = [100, 200,300])
plt.show()
# Out:
# [1 2 3] [0.4359949  0.02592623 0.54966248]

# %%
np.random.seed(2)
x = np.arange(1,4)
y = np.random.rand(3)
print(x,y)

# 매개변수 추가하기
# s (scale) = [요소의 개수만큼 크기 숫자를 작성]
plt.scatter(x, y, s = [100, 200,300], c=['r','c','y'])
plt.show()
# Out:
# [1 2 3] [0.4359949  0.02592623 0.54966248]

# %%
np.random.seed(2)
x = np.arange(1,4)
y = np.random.rand(3)
print(x,y)

# 매개변수 추가하기
# cmap  https://matplotlib.org/stable/tutorials/colors/colormaps.html
# 색상 팔레트 사용
# cmap 사용시 c = range(개수)로 범위를 지정

plt.scatter(x, y, s = [100, 200,300], c=range(3), cmap = 'cool')
plt.colorbar()
plt.show()
# Out:
# [1 2 3] [0.4359949  0.02592623 0.54966248]

# %% [markdown]
# ## Pie 차트

# %%
# 사용법 : plt.pie(size, labels = labels, autopct = 실수형)

# size : 파이차트의 크기를 담당하는 데이터
# labels : 각 부분의 라벨
# autopct : 자동으로 백분율을 계산해줌 %.1f%% -> 소수점 첫째자리까지 출력

sizes = [30,40,20,10]
labels = ['A','B','C','D']

plt.pie(sizes, labels = labels, autopct = '%.2f%%')
plt.legend()
plt.title('test pie chart')
plt.show()

# %%
# pie 차트의 colors

sizes = [30,40,20,10]
labels = ['A','B','C','D']
colors = sns.color_palette("ch:s=.25,rot=-.25")

# pie(colors = )
plt.pie(sizes, labels = labels, autopct = '%.1f%%', colors = colors)
plt.legend()
plt.title('test pie chart')
plt.show()

# %%
# pie 차트의 explode

sizes = [30,40,20,10, 5]
labels = ['A','B','C','D','E']
colors = sns.color_palette("ch:s=.25,rot=-.25")

# explode = [데이터의 개수에 맞게 작성] = 차트 강조할 때 많이 사용
# 0이 기준 0.1만큼 (10%) 원형차트 떨어지게 됩니다

plt.pie(sizes, labels = labels, autopct = '%.1f%%', colors = colors,
       explode = [0,0.1,0,0.2,0])
plt.legend()
plt.title('test pie chart')
plt.show()

# %%
sidoGender.head(2)
# Out:
#   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0    서울특별시  남자          4007         2849      2760        89          1158
# 1    서울특별시  여자          4440         2418      2347        72          2022
#
#    경제활동참가율(％)  고용률(%)  실업률(%)
# 0        71.1    68.9     3.1
# 1        54.5    52.9     3.0

# %% [markdown]
# ## 시도별 실업자 비율이 가장 높은 곳
#
# - 시도별로 묶기
# - 결측치 여부 확인 후 결측치 채워주기
# - 실업자(천명) 다 더하기

# %%
sido_sum = sidoGender.groupby('행정구역(시도)').sum()
sido_sum
# Out:
#             성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 행정구역(시도)
# 강원도       남자여자          1326          868       847        21           458
# 경기도       남자여자         11925         7843      7658       185          4081
# 경상남도      남자여자          2848         1796      1749        47          1052
# 경상북도      남자여자          2327         1527      1492        35           799
# 광주광역시     남자여자          1279          780       762        18           499
# 대구광역시     남자여자          2072         1264      1234        30           809
# 대전광역시     남자여자          1288          819       807        12           469
# 부산광역시     남자여자          2934         1741      1691        50          1193
# 서울특별시     남자여자          8447         5267      5107       161          3180
# 세종특별자치시   남자여자           314          205       202         3           110
# 울산광역시     남자여자           955          590       573        17           365
# 인천광역시     남자여자          2588         1687      1645        42           901
# 전라남도      남자여자          1525         1040      1025        14           484
# 전라북도      남자여자          1556         1001       986        16           555
# 제주특별자치도   남자여자           576          424       416         7           153
# 충청남도      남자여자          1913         1304      1282        22           609
# 충청북도      남자여자          1430          957       942        15           473
#
#           경제활동참가율(％)  고용률(%)  실업률(%)
# 행정구역(시도)
# 강원도            131.1   127.9     4.9
# 경기도            131.6   128.5     4.8
# 경상남도           126.1   122.8     5.2
# 경상북도           131.3   128.2     4.5
# 광주광역시          122.4   119.6     4.6
# 대구광역시          122.5   119.7     4.7
# 대전광역시          127.4   125.6     3.1
# 부산광역시          119.5   116.1     5.8
# 서울특별시          125.6   121.8     6.1
# 세종특별자치시        130.4   128.8     2.9
# 울산광역시          123.1   119.5     5.7
# 인천광역시          130.6   127.4     4.8
# 전라남도           136.5   134.4     2.7
# 전라북도           128.8   127.0     3.1
# 제주특별자치도        147.0   144.5     3.2
# 충청남도           135.9   133.7     3.4
# 충청북도           133.6   131.6     2.9

# %%
unemp_sum = sido_sum['실업자 (천명)']
unemp_sum
# Out:
# 행정구역(시도)
# 강원도         21
# 경기도        185
# 경상남도        47
# 경상북도        35
# 광주광역시       18
# 대구광역시       30
# 대전광역시       12
# 부산광역시       50
# 서울특별시      161
# 세종특별자치시      3
# 울산광역시       17
# 인천광역시       42
# 전라남도        14
# 전라북도        16
# 제주특별자치도      7
# 충청남도        22
# 충청북도        15
# Name: 실업자 (천명), dtype: int64

# %%
unemp_sum.index
# Out:
# Index(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도', '충청남도',
#        '충청북도'],
#       dtype='object', name='행정구역(시도)')

# %%
plt.pie(unemp_sum.values, labels = unemp_sum.index, autopct = '%.1f%%')
# legend 위치 이동시키기
plt.legend(bbox_to_anchor=(1.3, 1.0), loc="upper left")
plt.show()

#matplotlib 스타일 설정
plt.style.use('ggplot')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
traffic = pd.read_csv('data/도로교통공단_사망 교통사고 정보_20221231.csv', encoding='euc-kr')
traffic.head(5)
# Out:
#     발생년            발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도 발생지시군구  \
# 0  2022  2022-01-01 10:00  주  토     1     0     0     0       0    전남    순천시
# 1  2022  2022-01-01 14:00  주  토     1     0     0     0       0    전북    전주시
# 2  2022  2022-01-01 17:00  주  토     1     0     0     0       0    경기    연천군
# 3  2022  2022-01-01 20:00  야  토     1     0     0     0       0    부산    기장군
# 4  2022  2022-01-02 06:00  주  일     1     0     0     0       0    서울   서대문구
#
#   사고유형_대분류 사고유형_중분류     사고유형      가해자법규위반 도로형태_대분류   도로형태 가해자_당사자종별 피해자_당사자종별  \
# 0     차량단독    공작물충돌    공작물충돌  안전운전 의무 불이행      단일로    교량위       승용차        없음
# 1      차대차       추돌       추돌  안전운전 의무 불이행      단일로  기타단일로  원동기장치자전거       승용차
# 2     차량단독     도로이탈  도로이탈 추락  안전운전 의무 불이행      단일로  기타단일로       이륜차        없음
# 3      차대차       기타       기타  안전운전 의무 불이행      단일로  고가도로위       승용차       승용차
# 4     차대사람      횡단중      횡단중  안전운전 의무 불이행      단일로  기타단일로       승합차       보행자
#
#    발생위치X_UTMK  발생위치Y_UTMK          경도         위도
# 0     1000059     1660526  127.500646  34.939564
# 1      965929     1760951  127.122710  35.844490
# 2      966667     2021002  127.119365  38.188669
# 3     1156990     1697307  129.225773  35.258920
# 4      950217     1953529  126.936182  37.579800

# %%
# 데이터 프레임의 정보를 모두 출력
pd.set_option('display.max_columns', None) # 모든 컬럼을 출력

# 모든 행을 출력
# pd.set_option('display.max_rows', None)

# %%
traffic.head(10)
# Out:
#     발생년            발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도 발생지시군구  \
# 0  2022  2022-01-01 10:00  주  토     1     0     0     0       0    전남    순천시
# 1  2022  2022-01-01 14:00  주  토     1     0     0     0       0    전북    전주시
# 2  2022  2022-01-01 17:00  주  토     1     0     0     0       0    경기    연천군
# 3  2022  2022-01-01 20:00  야  토     1     0     0     0       0    부산    기장군
# 4  2022  2022-01-02 06:00  주  일     1     0     0     0       0    서울   서대문구
# 5  2022  2022-01-02 20:00  야  일     1     0     0     0       0    부산    기장군
# 6  2022  2022-01-02 21:00  야  일     1     0     0     0       0    인천   미추홀구
# 7  2022  2022-01-03 04:00  야  월     1     1     0     1       0    경기    성남시
# 8  2022  2022-01-03 15:00  주  월     1     0     0     0       0    충북    청주시
# 9  2022  2022-01-03 15:00  주  월     1     1     1     0       0    경남    고성군
#
#   사고유형_대분류 사고유형_중분류     사고유형      가해자법규위반 도로형태_대분류      도로형태 가해자_당사자종별  \
# 0     차량단독    공작물충돌    공작물충돌  안전운전 의무 불이행      단일로       교량위       승용차
# 1      차대차       추돌       추돌  안전운전 의무 불이행      단일로     기타단일로  원동기장치자전거
# 2     차량단독     도로이탈  도로이탈 추락  안전운전 의무 불이행      단일로     기타단일로       이륜차
# 3      차대차       기타       기타  안전운전 의무 불이행      단일로     고가도로위       승용차
# 4     차대사람      횡단중      횡단중  안전운전 의무 불이행      단일로     기타단일로       승합차
# 5      차대차     측면충돌     측면충돌     안전거리 미확보      단일로     기타단일로       승용차
# 6     차대사람    차도통행중    차도통행중           기타      단일로     기타단일로       승용차
# 7      차대차       추돌       추돌  안전운전 의무 불이행       기타        기타       화물차
# 8     차대사람      횡단중      횡단중         신호위반      교차로  교차로횡단보도내       승합차
# 9      차대차       추돌       추돌  안전운전 의무 불이행      단일로     기타단일로       화물차
#
#   피해자_당사자종별  발생위치X_UTMK  발생위치Y_UTMK          경도         위도
# 0        없음     1000059     1660526  127.500646  34.939564
# 1       승용차      965929     1760951  127.122710  35.844490
# 2        없음      966667     2021002  127.119365  38.188669
# 3       승용차     1156990     1697307  129.225773  35.258920
# 4       보행자      950217     1953529  126.936182  37.579800
# 5       이륜차     1152580     1704921  129.178730  35.328228
# 6       보행자      927256     1940265  126.677472  37.458727
# 7       화물차      968126     1936615  127.139739  37.428141
# 8       보행자     1000319     1848214  127.503568  36.631809
# 9       화물차     1076602     1669205  128.339601  35.014923

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2658 entries, 0 to 2657
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   발생년         2658 non-null   int64
#  1   발생년월일시      2658 non-null   object
#  2   주야          2658 non-null   object
#  3   요일          2658 non-null   object
#  4   사망자수        2658 non-null   int64
#  5   부상자수        2658 non-null   int64
#  6   중상자수        2658 non-null   int64
#  7   경상자수        2658 non-null   int64
#  8   부상신고자수      2658 non-null   int64
#  9   발생지시도       2658 non-null   object
#  10  발생지시군구      2658 non-null   object
#  11  사고유형_대분류    2658 non-null   object
#  12  사고유형_중분류    2658 non-null   object
#  13  사고유형        2658 non-null   object
#  14  가해자법규위반     2658 non-null   object
#  15  도로형태_대분류    2658 non-null   object
#  16  도로형태        2658 non-null   object
#  17  가해자_당사자종별   2658 non-null   object
#  18  피해자_당사자종별   2658 non-null   object
#  19  발생위치X_UTMK  2658 non-null   int64
#  20  발생위치Y_UTMK  2658 non-null   int64
#  21  경도          2658 non-null   float64
#  22  위도          2658 non-null   float64
# dtypes: float64(2), int64(8), object(13)
# memory usage: 477.7+ KB

# %% [markdown]
# ##### 예제
# 1. 요일별 교통사고 발생건수 막대그래프 시각화
# 2. 월별 사상자수 시각화(사망 + 부상)
# 3. 차대차 사건중 사망자가 많은 발생자 시도를 알아보고 시각화
# 4. 교통사고가 가장 많이 일어나는 시간대 알아보고 시각화

# %% [markdown]
# ## 1.요일별 교통사고 발생건수 막대그래프 시각화

# %%
week_sum = traffic.groupby('요일', as_index=False).agg(week = ('요일','count'))
week_sum
# Out:
#   요일  week
# 0  금   412
# 1  목   391
# 2  수   380
# 3  월   373
# 4  일   309
# 5  토   382
# 6  화   411

# %%
plt.bar(week_sum['요일'],week_sum['week'])
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ## 2.월별 사상자수 시각화(사망 + 부상)

# %%
traffic_month = traffic['발생년월일시'].str[6:7]
traffic_month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2653    2
# 2654    2
# 2655    2
# 2656    2
# 2657    2
# Name: 발생년월일시, Length: 2658, dtype: object

# %%
traffic.groupby('traffic_month').agg(cnt1 = ('사망자수','count'), cnt2 = ('부상자수','count'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 traffic.groupby('traffic_month').agg(cnt1 = ('사망자수','count'), cnt2 = ('부상자수','count'))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'traffic_month'

# %%
plt.bar(month_sum['월'], month_sum['month'])
# Out:
# <BarContainer object of 10 artists>

# %%
# groupby로 제조사별로 묶기
# agg사용
mpg_copy.groupby('제조사').agg(city_mean = ('도시','mean'), high_mean = ('고속도로','mean'))

# 제조사 별로 그룹을 묶은 후
# 제조사 별 등급(grade컬럼)을 나누기
# 예- audi A등급, B등급이 몇개인가?

# 그룹을 다시 나눌땐
# groupby시 [] 한번 더 감싸서 진행!
mpg_copy.groupby(['제조사','grade']).agg(grade_cnt = ('grade', 'count'))
